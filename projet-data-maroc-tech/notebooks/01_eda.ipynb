# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
df = pd.read_csv('../data/raw/Rekrute.csv')

# %%
df.head()
# Out:
#      offer_id scrape_date            scrape_timestamp  \
# 0  846932618F  2026-06-16  2026-06-16T14:05:33.422004
# 1  35C4397FD9  2026-06-16  2026-06-16T14:05:33.740498
# 2  D3E682961F  2026-06-16  2026-06-16T14:05:33.890840
# 3  3982EE759A  2026-06-16  2026-06-16T14:05:34.188578
# 4  2370F10D20  2026-06-16  2026-06-16T14:05:34.869485
#
#                                      titre_poste  entreprise  \
# 0                Project Management Office (PMO)        Atos
# 1  Stage en coordination mobilité internationale        Atos
# 2               Chefs de Projets Techniques .NET  Sqli Maroc
# 3        Développeur Front End Angular JS en CDI      Welink
# 4        Développeur Front End Angular JS en CDI      Welink
#
#                                   secteur_entreprise  taille_entreprise  \
# 0  Gestion projet / Etudes / R&D- Informatique / ...                NaN
# 1                                       Informatique                NaN
# ...

# %%
df.shape
# Out:
# (10782, 42)

# %%
# View information about the DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10782 entries, 0 to 10781
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   offer_id                  10782 non-null  str
#  1   scrape_date               10782 non-null  str
#  2   scrape_timestamp          10782 non-null  str
#  3   titre_poste               10782 non-null  str
#  4   entreprise                10782 non-null  str
#  5   secteur_entreprise        10782 non-null  str
#  6   taille_entreprise         0 non-null      float64
#  7   ville                     10782 non-null  str
#  8   ville_normalized          10782 non-null  str
#  9   region                    9975 non-null   str
#  10  type_contrat              10768 non-null  str
#  11  type_contrat_normalized   10768 non-null  str
#  12  modalite_travail          10782 non-null  str
#  13  is_remote                 10782 non-null  int64
# ...

# %%
df.describe()
# Out:
#        taille_entreprise     is_remote     is_hybrid  is_onsite  \
# count                0.0  10782.000000  10782.000000    10782.0
# mean                 NaN      0.794751      0.205249        0.0
# std                  NaN      0.403903      0.403903        0.0
# min                  NaN      0.000000      0.000000        0.0
# 25%                  NaN      1.000000      0.000000        0.0
# 50%                  NaN      1.000000      0.000000        0.0
# 75%                  NaN      1.000000      0.000000        0.0
# max                  NaN      1.000000      1.000000        0.0
#
#        experience_years_min  experience_years_max  sous_fonction  \
# count          10782.000000          10782.000000            0.0
# mean               3.080597              5.886848            NaN
# std                1.888973              3.744110            NaN
# min                0.000000              0.000000            NaN
# ...

# %%
df.isnull().sum()
# Out:
# offer_id                        0
# scrape_date                     0
# scrape_timestamp                0
# titre_poste                     0
# entreprise                      0
# secteur_entreprise              0
# taille_entreprise           10782
# ville                           0
# ville_normalized                0
# region                        807
# type_contrat                   14
# type_contrat_normalized        14
# modalite_travail                0
# is_remote                       0
# is_hybrid                       0
# is_onsite                       0
# niveau_etudes                  14
# niveau_etudes_normalized       14
# experience_requise              1
# experience_years_min            0
# experience_years_max            0
# langue                       5805
# secteur_activite                0
# sous_secteur                 6168
# fonction                     6168
# sous_fonction               10782
# hard_skills                  3206
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
